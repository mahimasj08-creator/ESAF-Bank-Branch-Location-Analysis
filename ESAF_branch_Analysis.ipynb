# %%
#!pip install openpyxl
#!pip install matplotlib
#!pip install scikit-learn

# %%
#!pip install pdfplumber
#!pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Arial'
import pdfplumber

# %%
df=pd.read_csv('Population_States.csv',header=3)

# %%
df
# Out:
#                                 State/Union Territory     1951     1961  \
# 0                           Andaman & Nicobar Islands       31       64
# 1                                      Andhra Pradesh   31,115   35,983
# 2                                   Arunachal Pradesh        -      337
# 3                                               Assam    8,029   10,837
# 4                                               Bihar   29,085   34,841
# 5                                          Chandigarh       24      120
# 6                                        Chhattisgarh    7,457    9,154
# 7                                Dadra & Nagar Haveli       42       58
# 8                                         Daman & Diu       49       37
# 9                                               Delhi    1,744    2,659
# 10                                                Goa      547      590
# 11                                            Gujarat   16,263   20,633
# ...

# %%
df=df.iloc[:-7]
df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       31       64      115      189      281
# 1              Andhra Pradesh   31,115   35,983   43,503   53,551   66,508
# 2           Arunachal Pradesh        -      337      468      632      865
# 3                       Assam    8,029   10,837   14,625   18,041   22,414
# 4                       Bihar   29,085   34,841   42,126   52,303   64,531
# 5                  Chandigarh       24      120      257      452      642
# 6                Chhattisgarh    7,457    9,154   11,637   14,010   17,615
# 7        Dadra & Nagar Haveli       42       58       74      104      138
# 8                 Daman & Diu       49       37       63       79      102
# 9                       Delhi    1,744    2,659    4,066    6,220    9,421
# 10                        Goa      547      590      795    1,008    1,170
# ...

# %%
df.describe()
# Out:
#             State/Union Territory 1951 1961 1971 1981 1991 2001 2011
# count                          36   36   36   36   36   36   36   36
# unique                         36   36   35   36   36   36   36   36
# top     Andaman & Nicobar Islands   31  369  115  189  281  356  381
# freq                            1    1    2    1    1    1    1    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State/Union Territory  36 non-null     object
#  1   1951                   36 non-null     object
#  2   1961                   36 non-null     object
#  3   1971                   36 non-null     object
#  4   1981                   36 non-null     object
#  5   1991                   36 non-null     object
#  6   2001                   36 non-null     object
#  7   2011                   36 non-null     object
# dtypes: object(8)
# memory usage: 2.4+ KB

# %%
print(df[df == '-'].count())
# Out:
# State/Union Territory    0
# 1951                     1
# 1961                     0
# 1971                     0
# 1981                     0
# 1991                     0
# 2001                     0
# 2011                     0
# dtype: int64

# %%
df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       31       64      115      189      281
# 1              Andhra Pradesh   31,115   35,983   43,503   53,551   66,508
# 2           Arunachal Pradesh        -      337      468      632      865
# 3                       Assam    8,029   10,837   14,625   18,041   22,414
# 4                       Bihar   29,085   34,841   42,126   52,303   64,531
# 5                  Chandigarh       24      120      257      452      642
# 6                Chhattisgarh    7,457    9,154   11,637   14,010   17,615
# 7        Dadra & Nagar Haveli       42       58       74      104      138
# 8                 Daman & Diu       49       37       63       79      102
# 9                       Delhi    1,744    2,659    4,066    6,220    9,421
# 10                        Goa      547      590      795    1,008    1,170
# ...

# %%
df.replace(inplace=True)
# Out:
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\2900154523.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df.replace(inplace=True)

# %%
df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       31       64      115      189      281
# 1              Andhra Pradesh   31,115   35,983   43,503   53,551   66,508
# 2           Arunachal Pradesh        -      337      468      632      865
# 3                       Assam    8,029   10,837   14,625   18,041   22,414
# 4                       Bihar   29,085   34,841   42,126   52,303   64,531
# 5                  Chandigarh       24      120      257      452      642
# 6                Chhattisgarh    7,457    9,154   11,637   14,010   17,615
# 7        Dadra & Nagar Haveli       42       58       74      104      138
# 8                 Daman & Diu       49       37       63       79      102
# 9                       Delhi    1,744    2,659    4,066    6,220    9,421
# 10                        Goa      547      590      795    1,008    1,170
# ...

# %%
df['1951'] = df['1951'].replace('-', 0)
# Out:
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\3060460719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['1951'] = df['1951'].replace('-', 0)

# %%
df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       31       64      115      189      281
# 1              Andhra Pradesh   31,115   35,983   43,503   53,551   66,508
# 2           Arunachal Pradesh        0      337      468      632      865
# 3                       Assam    8,029   10,837   14,625   18,041   22,414
# 4                       Bihar   29,085   34,841   42,126   52,303   64,531
# 5                  Chandigarh       24      120      257      452      642
# 6                Chhattisgarh    7,457    9,154   11,637   14,010   17,615
# 7        Dadra & Nagar Haveli       42       58       74      104      138
# 8                 Daman & Diu       49       37       63       79      102
# 9                       Delhi    1,744    2,659    4,066    6,220    9,421
# 10                        Goa      547      590      795    1,008    1,170
# ...

# %%
df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       31       64      115      189      281
# 1              Andhra Pradesh   31,115   35,983   43,503   53,551   66,508
# 2           Arunachal Pradesh        0      337      468      632      865
# 3                       Assam    8,029   10,837   14,625   18,041   22,414
# 4                       Bihar   29,085   34,841   42,126   52,303   64,531
# 5                  Chandigarh       24      120      257      452      642
# 6                Chhattisgarh    7,457    9,154   11,637   14,010   17,615
# 7        Dadra & Nagar Haveli       42       58       74      104      138
# 8                 Daman & Diu       49       37       63       79      102
# 9                       Delhi    1,744    2,659    4,066    6,220    9,421
# 10                        Goa      547      590      795    1,008    1,170
# ...

# %%
years=['1951','1961','1971','1981','1991','2001','2011']

# %%
for year in years:
    df[year] = df[year].str.replace(',', '', regex=True)  # Remove commas
    df[year] = pd.to_numeric(df[year], errors='coerce')   # Convert to numeric, NaNs if invalid
    df[year] = df[year].fillna(0).astype(int)             # Replace NaN with 0, then convert
# Out:
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\2128348978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[year] = df[year].str.replace(',', '', regex=True)  # Remove commas
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\2128348978.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[year] = pd.to_numeric(df[year], errors='coerce')   # Convert to numeric, NaNs if invalid
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\2128348978.py:4: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#         State/Union Territory    1951    1961    1971    1981    1991  \
# 0   Andaman & Nicobar Islands      31      64     115     189     281
# 1              Andhra Pradesh   31115   35983   43503   53551   66508
# 2           Arunachal Pradesh       0     337     468     632     865
# 3                       Assam    8029   10837   14625   18041   22414
# 4                       Bihar   29085   34841   42126   52303   64531
# 5                  Chandigarh      24     120     257     452     642
# 6                Chhattisgarh    7457    9154   11637   14010   17615
# 7        Dadra & Nagar Haveli      42      58      74     104     138
# 8                 Daman & Diu      49      37      63      79     102
# 9                       Delhi    1744    2659    4066    6220    9421
# 10                        Goa     547     590     795    1008    1170
# 11                    Gujarat   16263   20633   26697   34086   41310
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State/Union Territory  36 non-null     object
#  1   1951                   36 non-null     int64
#  2   1961                   36 non-null     int64
#  3   1971                   36 non-null     int64
#  4   1981                   36 non-null     int64
#  5   1991                   36 non-null     int64
#  6   2001                   36 non-null     int64
#  7   2011                   36 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 2.4+ KB

# %%
df.to_csv('Population_new',index=False)

# %%
df=pd.read_csv('Population_new')

# %%
top_10_df=df.sort_values(by='2011',ascending=False)
#top_10_df=top_10_df.head(10)
top_10_df=top_10_df.iloc[1:11]

# %%
#top_10_df=df.sort_values(by='2011',ascending=False)
#top_10_df=top_10_df.head(10)

top_10_df
# Out:
#    State/Union Territory   1951   1961   1971    1981    1991    2001    2011
# 32         Uttar Pradesh  60274  70144  83849  105137  132062  166198  199812
# 20           Maharashtra  32003  39554  50412   62783   78937   96879  112374
# 4                  Bihar  29085  34841  42126   52303   64531   82999  104099
# 34           West Bengal  26300  34926  44312   54581   68078   80176   91276
# 1         Andhra Pradesh  31115  35983  43503   53551   66508   76210   84581
# 19        Madhya Pradesh  18615  23218  30017   38169   48566   60348   72627
# 30            Tamil Nadu  30119  33687  41199   48408   55859   62406   72147
# 28             Rajasthan  15971  20156  25766   34262   44006   56507   68548
# 16             Karnataka  19402  23587  29299   37136   44977   52851   61095
# 11               Gujarat  16263  20633  26697   34086   41310   50671   60440

# %%
plt.bar(top_10_df['State/Union Territory'],top_10_df['2011'],color="pink")
plt.xlabel("State/Union Territory")
plt.ylabel('Population')
plt.title('Top 10 Populated States')
plt.xticks(rotation=45)
plt.show()

# %%
bottom_10_df=df.sort_values(by='2011',ascending=True)
bottom_10_df=bottom_10_df.iloc[1:11]

# %%
bottom_10_df
# Out:
#         State/Union Territory  1951  1961  1971  1981  1991  2001  2011
# 8                 Daman & Diu    49    37    63    79   102   158   243
# 7        Dadra & Nagar Haveli    42    58    74   104   138   220   344
# 0   Andaman & Nicobar Islands    31    64   115   189   281   356   381
# 29                     Sikkim   138   162   210   316   406   541   611
# 5                  Chandigarh    24   120   257   452   642   901  1055
# 23                    Mizoram   196   266   332   494   690   889  1097
# 26                 Puducherry   317   369   472   604   808   974  1248
# 2           Arunachal Pradesh     0   337   468   632   865  1098  1384
# 10                        Goa   547   590   795  1008  1170  1348  1459
# 24                   Nagaland   213   369   516   775  1210  1990  1979

# %%
plt.bar(bottom_10_df['State/Union Territory'],bottom_10_df['2011'],color="yellow")
plt.xlabel("State/Union Territory",fontsize=10)
plt.ylabel('Population')
plt.title('Bottom 10 Populated States',fontweight='bold', fontname='Calibri')
plt.xticks(rotation=45, fontsize=8,ha='right')
plt.tight_layout()
plt.show()

# %%
df_long=pd.melt(top_10_df,id_vars='State/Union Territory',var_name='Years',value_name='Population')

# %%
df_long
# Out:
#    State/Union Territory Years  Population
# 0          Uttar Pradesh  1951       60274
# 1            Maharashtra  1951       32003
# 2                  Bihar  1951       29085
# 3            West Bengal  1951       26300
# 4         Andhra Pradesh  1951       31115
# ..                   ...   ...         ...
# 65        Madhya Pradesh  2011       72627
# 66            Tamil Nadu  2011       72147
# 67             Rajasthan  2011       68548
# 68             Karnataka  2011       61095
# 69               Gujarat  2011       60440
#
# [70 rows x 3 columns]

# %%
print(df_long.shape)
print(df.shape)
# Out:
# (70, 3)
# (36, 8)

# %%
print(top_10_df.shape)
# Out:
# (10, 8)

# %%
plt.figure(figsize=(12, 6))

for state in df_long['State/Union Territory'].unique():
    state_data = df_long[df_long['State/Union Territory'] == state]
    plt.plot(state_data['Years'], state_data['Population'], label=state)

plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Population Trend by State")
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_long_2=pd.melt(bottom_10_df,id_vars='State/Union Territory',var_name='Years',value_name='Population')
df_long_2
# Out:
#         State/Union Territory Years  Population
# 0                 Daman & Diu  1951          49
# 1        Dadra & Nagar Haveli  1951          42
# 2   Andaman & Nicobar Islands  1951          31
# 3                      Sikkim  1951         138
# 4                  Chandigarh  1951          24
# ..                        ...   ...         ...
# 65                    Mizoram  2011        1097
# 66                 Puducherry  2011        1248
# 67          Arunachal Pradesh  2011        1384
# 68                        Goa  2011        1459
# 69                   Nagaland  2011        1979
#
# [70 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))

for state in df_long_2['State/Union Territory'].unique():
    state_data = df_long_2[df_long_2['State/Union Territory'] == state]
    plt.plot(state_data['Years'], state_data['Population'], label=state)

plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Population Trend by State")
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
        import pdfplumber
        import pandas as pd
        
        pdf_path = "financial_literacy_rate.pdf"
        table_data = []
        
        with pdfplumber.open(pdf_path) as pdf:
            for i in [3, 4]:  # Pages 4 and 5
                page = pdf.pages[i]
                print(page)
                tables = page.extract_tables()
                print(tables)
                
                for table in tables:
                    for row in table:
                        # Skip if row is too short or malformed
                        if row and len(row) > 1:
                            # Replace \n with space in each cell
                            cleaned_row = [cell.replace('\n', ' ') if cell else '' for cell in row]
                            print(cleaned_row)
                            table_data.append(cleaned_row)
        
        # Create dataframe with proper header
        columns = table_data[1]
        print(columns)
        data = table_data[2:-1]
        print(data)
        
        f_df = pd.DataFrame(data, columns=columns)
        print(f_df)
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# <Page:4>
# ...

# %%
f_df
# Out:
#                   States and UTs High Knowledge score High Behaviour score  \
# 0   Andhra Pradesh and Telengana               46.90%               32.70%
# 1              Arunachal Pradesh               83.30%               51.10%
# 2                          Assam               49.50%               17.70%
# 3                          Bihar               32.90%               41.80%
# 4                     Chandigarh               11.00%               68.10%
# 5                   Chhattisgarh               47.40%               22.80%
# 6           Dadra & Nagar Haveli               26.50%               20.60%
# 7                  Daman and Diu               49.00%               19.60%
# 8                          Delhi               51.40%               36.60%
# 9                        Gujarat               31.90%               18.40%
# 10                       Haryana               58.90%               46.80%
# ...

# %%
f_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   States and UTs               27 non-null     object
#  1   High Knowledge score         27 non-null     object
#  2   High Behaviour score         27 non-null     object
#  3   High Attitude score          27 non-null     object
#  4   High financial literacy      27 non-null     object
#  5   Rank in Financial knowledge  27 non-null     object
#  6   Rank in financial Behaviour  27 non-null     object
#  7   Rank in Financial Attitude   27 non-null     object
#  8   Rank in Financial literacy   27 non-null     object
# dtypes: object(9)
# memory usage: 2.0+ KB

# %%
print(f_df.columns.tolist())
f_df.columns=f_df.columns.str.strip()
p_col = ['High Knowledge score', 'High Behaviour score', 'High Attitude score', 'High financial literacy']

for col in p_col:
    f_df[col]=f_df[col].str.replace('%','').astype(float)
# Out:
# ['States and UTs', 'High Knowledge score', 'High Behaviour score', 'High Attitude score', 'High financial literacy', 'Rank in Financial knowledge', 'Rank in financial Behaviour', 'Rank in Financial Attitude', 'Rank in Financial literacy']

# %%
f_df
# Out:
#                   States and UTs  High Knowledge score  High Behaviour score  \
# 0   Andhra Pradesh and Telengana                  46.9                  32.7
# 1              Arunachal Pradesh                  83.3                  51.1
# 2                          Assam                  49.5                  17.7
# 3                          Bihar                  32.9                  41.8
# 4                     Chandigarh                  11.0                  68.1
# 5                   Chhattisgarh                  47.4                  22.8
# 6           Dadra & Nagar Haveli                  26.5                  20.6
# 7                  Daman and Diu                  49.0                  19.6
# 8                          Delhi                  51.4                  36.6
# 9                        Gujarat                  31.9                  18.4
# 10                       Haryana                  58.9                  46.8
# ...

# %%
f_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   States and UTs               27 non-null     object
#  1   High Knowledge score         27 non-null     float64
#  2   High Behaviour score         27 non-null     float64
#  3   High Attitude score          27 non-null     float64
#  4   High financial literacy      27 non-null     float64
#  5   Rank in Financial knowledge  27 non-null     object
#  6   Rank in financial Behaviour  27 non-null     object
#  7   Rank in Financial Attitude   27 non-null     object
#  8   Rank in Financial literacy   27 non-null     object
# dtypes: float64(4), object(5)
# memory usage: 2.0+ KB

# %%
df['State/Union Territory'] = df['State/Union Territory'].str.strip()
f_df['States and UTs'] = f_df['States and UTs'].str.strip()
f_data= f_df[f_df['States and UTs'].isin(df['State/Union Territory'])]
#f_df = f_df.set_index('States and UTs').reindex(df['State/Union Territory']).reset_index()

# %%
print(f_df)
# Out:
#                   States and UTs  High Knowledge score  High Behaviour score  \
# 0   Andhra Pradesh and Telengana                  46.9                  32.7
# 1              Arunachal Pradesh                  83.3                  51.1
# 2                          Assam                  49.5                  17.7
# 3                          Bihar                  32.9                  41.8
# 4                     Chandigarh                  11.0                  68.1
# 5                   Chhattisgarh                  47.4                  22.8
# 6           Dadra & Nagar Haveli                  26.5                  20.6
# 7                  Daman and Diu                  49.0                  19.6
# 8                          Delhi                  51.4                  36.6
# 9                        Gujarat                  31.9                  18.4
# 10                       Haryana                  58.9                  46.8
# ...

# %%
print(df)
# Out:
#         State/Union Territory    1951    1961    1971    1981    1991  \
# 0   Andaman & Nicobar Islands      31      64     115     189     281
# 1              Andhra Pradesh   31115   35983   43503   53551   66508
# 2           Arunachal Pradesh       0     337     468     632     865
# 3                       Assam    8029   10837   14625   18041   22414
# 4                       Bihar   29085   34841   42126   52303   64531
# 5                  Chandigarh      24     120     257     452     642
# 6                Chhattisgarh    7457    9154   11637   14010   17615
# 7        Dadra & Nagar Haveli      42      58      74     104     138
# 8                 Daman & Diu      49      37      63      79     102
# 9                       Delhi    1744    2659    4066    6220    9421
# 10                        Goa     547     590     795    1008    1170
# 11                    Gujarat   16263   20633   26697   34086   41310
# ...

# %%
f_data
# Out:
#           States and UTs  High Knowledge score  High Behaviour score  \
# 1      Arunachal Pradesh                  83.3                  51.1
# 2                  Assam                  49.5                  17.7
# 3                  Bihar                  32.9                  41.8
# 4             Chandigarh                  11.0                  68.1
# 5           Chhattisgarh                  47.4                  22.8
# 6   Dadra & Nagar Haveli                  26.5                  20.6
# 8                  Delhi                  51.4                  36.6
# 9                Gujarat                  31.9                  18.4
# 10               Haryana                  58.9                  46.8
# 11      Himachal Pradesh                  59.4                  55.4
# 12             Jharkhand                  48.1                  29.4
# 13             Karnataka                  49.7                  39.2
# 14                Kerala                  54.4                  32.2
# ...

# %%
f_df.to_csv('financial_literacy_2',index=False)

# %%
pd.read_csv('financial_literacy_2')
# Out:
#                   States and UTs  High Knowledge score  High Behaviour score  \
# 0   Andhra Pradesh and Telengana                  46.9                  32.7
# 1              Arunachal Pradesh                  83.3                  51.1
# 2                          Assam                  49.5                  17.7
# 3                          Bihar                  32.9                  41.8
# 4                     Chandigarh                  11.0                  68.1
# 5                   Chhattisgarh                  47.4                  22.8
# 6           Dadra & Nagar Haveli                  26.5                  20.6
# 7                  Daman and Diu                  49.0                  19.6
# 8                          Delhi                  51.4                  36.6
# 9                        Gujarat                  31.9                  18.4
# 10                       Haryana                  58.9                  46.8
# ...

# %%
df
# Out:
#         State/Union Territory    1951    1961    1971    1981    1991  \
# 0   Andaman & Nicobar Islands      31      64     115     189     281
# 1              Andhra Pradesh   31115   35983   43503   53551   66508
# 2           Arunachal Pradesh       0     337     468     632     865
# 3                       Assam    8029   10837   14625   18041   22414
# 4                       Bihar   29085   34841   42126   52303   64531
# 5                  Chandigarh      24     120     257     452     642
# 6                Chhattisgarh    7457    9154   11637   14010   17615
# 7        Dadra & Nagar Haveli      42      58      74     104     138
# 8                 Daman & Diu      49      37      63      79     102
# 9                       Delhi    1744    2659    4066    6220    9421
# 10                        Goa     547     590     795    1008    1170
# 11                    Gujarat   16263   20633   26697   34086   41310
# ...

# %%
fin_data = pd.read_csv("financial_literacy_2.txt", delimiter=",")

# %%
#fin_data
df
# Out:
#         State/Union Territory    1951    1961    1971    1981    1991  \
# 0   Andaman & Nicobar Islands      31      64     115     189     281
# 1              Andhra Pradesh   31115   35983   43503   53551   66508
# 2           Arunachal Pradesh       0     337     468     632     865
# 3                       Assam    8029   10837   14625   18041   22414
# 4                       Bihar   29085   34841   42126   52303   64531
# 5                  Chandigarh      24     120     257     452     642
# 6                Chhattisgarh    7457    9154   11637   14010   17615
# 7        Dadra & Nagar Haveli      42      58      74     104     138
# 8                 Daman & Diu      49      37      63      79     102
# 9                       Delhi    1744    2659    4066    6220    9421
# 10                        Goa     547     590     795    1008    1170
# 11                    Gujarat   16263   20633   26697   34086   41310
# ...

# %%
df=pd.read_csv('Population_new')
df
# Out:
#         State/Union Territory    1951    1961    1971    1981    1991  \
# 0   Andaman & Nicobar Islands      31      64     115     189     281
# 1              Andhra Pradesh   31115   35983   43503   53551   66508
# 2           Arunachal Pradesh       0     337     468     632     865
# 3                       Assam    8029   10837   14625   18041   22414
# 4                       Bihar   29085   34841   42126   52303   64531
# 5                  Chandigarh      24     120     257     452     642
# 6                Chhattisgarh    7457    9154   11637   14010   17615
# 7        Dadra & Nagar Haveli      42      58      74     104     138
# 8                 Daman & Diu      49      37      63      79     102
# 9                       Delhi    1744    2659    4066    6220    9421
# 10                        Goa     547     590     795    1008    1170
# 11                    Gujarat   16263   20633   26697   34086   41310
# ...

# %%
merge_data=pd.merge(df,fin_data,left_on='State/Union Territory',right_on='States and UTs',how='inner')

# %%
merge_data
# Out:
#    State/Union Territory   1951   1961   1971    1981    1991    2001    2011  \
# 0         Andhra Pradesh  31115  35983  43503   53551   66508   76210   84581
# 1      Arunachal Pradesh      0    337    468     632     865    1098    1384
# 2                  Assam   8029  10837  14625   18041   22414   26656   31206
# 3                  Bihar  29085  34841  42126   52303   64531   82999  104099
# 4             Chandigarh     24    120    257     452     642     901    1055
# 5           Chhattisgarh   7457   9154  11637   14010   17615   20834   25545
# 6   Dadra & Nagar Haveli     42     58     74     104     138     220     344
# 7                  Delhi   1744   2659   4066    6220    9421   13851   16788
# 8                    Goa    547    590    795    1008    1170    1348    1459
# 9                Gujarat  16263  20633  26697   34086   41310   50671   60440
# 10               Haryana   5674   7591  10036   12922   16464   21145   25351
# ...

# %%
merge_data = merge_data.drop(columns=['States and UTs'])

# %%
merge_data
# Out:
#    State/Union Territory   1951   1961   1971    1981    1991    2001    2011  \
# 0         Andhra Pradesh  31115  35983  43503   53551   66508   76210   84581
# 1      Arunachal Pradesh      0    337    468     632     865    1098    1384
# 2                  Assam   8029  10837  14625   18041   22414   26656   31206
# 3                  Bihar  29085  34841  42126   52303   64531   82999  104099
# 4             Chandigarh     24    120    257     452     642     901    1055
# 5           Chhattisgarh   7457   9154  11637   14010   17615   20834   25545
# 6   Dadra & Nagar Haveli     42     58     74     104     138     220     344
# 7                  Delhi   1744   2659   4066    6220    9421   13851   16788
# 8                    Goa    547    590    795    1008    1170    1348    1459
# 9                Gujarat  16263  20633  26697   34086   41310   50671   60440
# 10               Haryana   5674   7591  10036   12922   16464   21145   25351
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(merge_data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation\xa0Matrix')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=merge_data, x='2011', y='High financial literacy')
plt.title("State Population vs Financial Literacy Rate")
plt.xlabel("Population")
plt.ylabel("Financial Literacy (%)")
plt.show()

# %%
years=['1951','1961','1971','1981','1991','2001']
ranks=['Rank in Financial knowledge','Rank in financial Behaviour','Rank in Financial Attitude','Rank in Financial literacy']
merge_data=merge_data.drop(columns=years)
merge_data
# Out:
#    State/Union Territory    2011  High Knowledge score  High Behaviour score  \
# 0         Andhra Pradesh   84581                  46.9                  32.7
# 1      Arunachal Pradesh    1384                  83.3                  51.1
# 2                  Assam   31206                  49.5                  17.7
# 3                  Bihar  104099                  32.9                  41.8
# 4             Chandigarh    1055                  11.0                  68.1
# 5           Chhattisgarh   25545                  47.4                  22.8
# 6   Dadra & Nagar Haveli     344                  26.5                  20.6
# 7                  Delhi   16788                  51.4                  36.6
# 8                    Goa    1459                  50.5                  16.2
# 9                Gujarat   60440                  31.9                  18.4
# 10               Haryana   25351                  58.9                  46.8
# ...

# %%
merge_data=merge_data.drop(columns=ranks)

# %%
merge_data
# Out:
#    State/Union Territory    2011  High Knowledge score  High Behaviour score  \
# 0         Andhra Pradesh   84581                  46.9                  32.7
# 1      Arunachal Pradesh    1384                  83.3                  51.1
# 2                  Assam   31206                  49.5                  17.7
# 3                  Bihar  104099                  32.9                  41.8
# 4             Chandigarh    1055                  11.0                  68.1
# 5           Chhattisgarh   25545                  47.4                  22.8
# 6   Dadra & Nagar Haveli     344                  26.5                  20.6
# 7                  Delhi   16788                  51.4                  36.6
# 8                    Goa    1459                  50.5                  16.2
# 9                Gujarat   60440                  31.9                  18.4
# 10               Haryana   25351                  58.9                  46.8
# ...

# %%
sns.heatmap(merge_data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation\xa0Matrix')

# %%
ex_data=pd.read_csv('bank_exist.csv')

# %%
ex_data
# Out:
#    State/Union Territory ESAF Branch Exists?
# 0         Andhra Pradesh                 Yes
# 1      Arunachal Pradesh                  No
# 2                  Assam                 Yes
# 3                  Bihar                 Yes
# 4           Chhattisgarh                 Yes
# 5                    Goa                  No
# 6                Gujarat                 Yes
# 7                Haryana                 Yes
# 8       Himachal Pradesh                  No
# 9      Jammu and Kashmir                  No
# 10             Jharkhand                 Yes
# 11             Karnataka                 Yes
# 12                Kerala                 Yes
# 13                Ladakh                  No
# 14        Madhya Pradesh                 Yes
# 15           Maharashtra                 Yes
# 16               Manipur                 Yes
# 17             Meghalaya                 Yes
# 18               Mizoram                  No
# 19              Nagaland                  No
# ...

# %%
merge_data=pd.merge(merge_data,ex_data,on='State/Union Territory')
merge_data
# Out:
#    State/Union Territory    2011  High Knowledge score  High Behaviour score  \
# 0         Andhra Pradesh   84581                  46.9                  32.7
# 1      Arunachal Pradesh    1384                  83.3                  51.1
# 2                  Assam   31206                  49.5                  17.7
# 3                  Bihar  104099                  32.9                  41.8
# 4           Chhattisgarh   25545                  47.4                  22.8
# 5                    Goa    1459                  50.5                  16.2
# 6                Gujarat   60440                  31.9                  18.4
# 7                Haryana   25351                  58.9                  46.8
# 8       Himachal Pradesh    6865                  59.4                  55.4
# 9              Jharkhand   32988                  48.1                  29.4
# 10             Karnataka   61095                  49.7                  39.2
# ...

# %%
merge_data.shape
# Out:
# (22, 7)

# %%
ex_data.shape
# Out:
# (32, 2)

# %%
merge_data['ESAF Branch Exists?']=merge_data['ESAF Branch Exists?'].map({'Yes':1,'No':0})
sns.heatmap(merge_data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix_2")
# Out:
# Text(0.5, 1.0, 'Correlation\xa0Matrix_2')

# %%
merge_data
# Out:
#    State/Union Territory    2011  High Knowledge score  High Behaviour score  \
# 0         Andhra Pradesh   84581                  46.9                  32.7
# 1      Arunachal Pradesh    1384                  83.3                  51.1
# 2                  Assam   31206                  49.5                  17.7
# 3                  Bihar  104099                  32.9                  41.8
# 4           Chhattisgarh   25545                  47.4                  22.8
# 5                    Goa    1459                  50.5                  16.2
# 6                Gujarat   60440                  31.9                  18.4
# 7                Haryana   25351                  58.9                  46.8
# 8       Himachal Pradesh    6865                  59.4                  55.4
# 9              Jharkhand   32988                  48.1                  29.4
# 10             Karnataka   61095                  49.7                  39.2
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=merge_data, x='ESAF Branch Exists?', y='2011')
plt.title("State Population vs Branch Existence")
plt.ylabel("yes/no")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=merge_data, x='ESAF Branch Exists?', y='High Knowledge score')
plt.title("State Population vs Knowledge score")
plt.ylabel("Knowledge score")
plt.show()

# %%
merge_data
# Out:
#    State/Union Territory    2011  High Knowledge score  High Behaviour score  \
# 0         Andhra Pradesh   84581                  46.9                  32.7
# 1      Arunachal Pradesh    1384                  83.3                  51.1
# 2                  Assam   31206                  49.5                  17.7
# 3                  Bihar  104099                  32.9                  41.8
# 4           Chhattisgarh   25545                  47.4                  22.8
# 5                    Goa    1459                  50.5                  16.2
# 6                Gujarat   60440                  31.9                  18.4
# 7                Haryana   25351                  58.9                  46.8
# 8       Himachal Pradesh    6865                  59.4                  55.4
# 9              Jharkhand   32988                  48.1                  29.4
# 10             Karnataka   61095                  49.7                  39.2
# ...

# %%
ex_data
# Out:
#    State/Union Territory ESAF Branch Exists?
# 0         Andhra Pradesh                 Yes
# 1      Arunachal Pradesh                  No
# 2                  Assam                 Yes
# 3                  Bihar                 Yes
# 4           Chhattisgarh                 Yes
# 5                    Goa                  No
# 6                Gujarat                 Yes
# 7                Haryana                 Yes
# 8       Himachal Pradesh                  No
# 9      Jammu and Kashmir                  No
# 10             Jharkhand                 Yes
# 11             Karnataka                 Yes
# 12                Kerala                 Yes
# 13                Ladakh                  No
# 14        Madhya Pradesh                 Yes
# 15           Maharashtra                 Yes
# 16               Manipur                 Yes
# 17             Meghalaya                 Yes
# 18               Mizoram                  No
# 19              Nagaland                  No
# ...

# %%
r_df=pd.read_csv('rural_pop.csv', header=2)

# %%
r_df
# Out:
#                                 State/Union Territory     1951     1961  \
# 0                           Andaman & Nicobar Islands       23       49
# 1                                      Andhra Pradesh   25,695   29,709
# 2                                   Arunachal Pradesh        -      337
# 3                                               Assam    7,684   10,056
# 4                                               Bihar   27,219   32,261
# 5                                          Chandigarh       24       21
# 6                                        Chhattisgarh    7,093    8,392
# 7                                Dadra & Nagar Haveli       42       58
# 8                                         Daman & Diu       30       23
# 9                                               Delhi      307      299
# 10                                                Goa      477      503
# 11                                            Gujarat   11,835   15,317
# ...

# %%
r_df=r_df.iloc[:-8]
r_df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       23       49       89      139      206
# 1              Andhra Pradesh   25,695   29,709   35,100   41,063   48,621
# 2           Arunachal Pradesh        -      337      450      590      754
# 3                       Assam    7,684   10,056   13,336   16,259   19,927
# 4                       Bihar   27,219   32,261   38,770   47,158   57,819
# 5                  Chandigarh       24       21       24       29       66
# 6                Chhattisgarh    7,093    8,392   10,430   11,952   14,550
# 7        Dadra & Nagar Haveli       42       58       74       97      127
# 8                 Daman & Diu       30       23       39       50       54
# 9                       Delhi      307      299      419      452      949
# 10                        Goa      477      503      592      685      690
# ...

# %%
r_df['1951'] = r_df['1951'].replace('-', 0)
# Out:
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\3834498860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df['1951'] = r_df['1951'].replace('-', 0)

# %%
r_df
# Out:
#         State/Union Territory     1951     1961     1971     1981     1991  \
# 0   Andaman & Nicobar Islands       23       49       89      139      206
# 1              Andhra Pradesh   25,695   29,709   35,100   41,063   48,621
# 2           Arunachal Pradesh        0      337      450      590      754
# 3                       Assam    7,684   10,056   13,336   16,259   19,927
# 4                       Bihar   27,219   32,261   38,770   47,158   57,819
# 5                  Chandigarh       24       21       24       29       66
# 6                Chhattisgarh    7,093    8,392   10,430   11,952   14,550
# 7        Dadra & Nagar Haveli       42       58       74       97      127
# 8                 Daman & Diu       30       23       39       50       54
# 9                       Delhi      307      299      419      452      949
# 10                        Goa      477      503      592      685      690
# ...

# %%
#years is already stored
years=['1951','1961','1971','1981','1991','2001','2011']
for year in years:
    r_df[year] = r_df[year].astype(str).str.replace(',', '', regex=True) # Remove commas
    r_df[year] = pd.to_numeric(r_df[year], errors='coerce')   # Convert to numeric, NaNs if invalid
    r_df[year] = r_df[year].fillna(0).astype(int)             # Replace NaN with 0, then convert
# Out:
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\2452537649.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df[year] = r_df[year].astype(str).str.replace(',', '', regex=True) # Remove commas
# C:\Users\mahim\AppData\Local\Temp\ipykernel_9908\2452537649.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r_df[year] = pd.to_numeric(r_df[year], errors='coerce')   # Convert to numeric, NaNs if invalid
# ...

# %%
r_df
# Out:
#         State/Union Territory    1951    1961    1971    1981    1991    2001  \
# 0   Andaman & Nicobar Islands      23      49      89     139     206     240
# 1              Andhra Pradesh   25695   29709   35100   41063   48621   55401
# 2           Arunachal Pradesh       0     337     450     590     754     870
# 3                       Assam    7684   10056   13336   16259   19927   23216
# 4                       Bihar   27219   32261   38770   47158   57819   74317
# 5                  Chandigarh      24      21      24      29      66      92
# 6                Chhattisgarh    7093    8392   10430   11952   14550   16648
# 7        Dadra & Nagar Haveli      42      58      74      97     127     170
# 8                 Daman & Diu      30      23      39      50      54     101
# 9                       Delhi     307     299     419     452     949     945
# 10                        Goa     477     503     592     685     690     677
# ...

# %%
top_10_r_df=r_df.sort_values(by='2011',ascending=False).iloc[1:11]

# %%
top_10_r_df
# Out:
#    State/Union Territory   1951   1961   1971   1981    1991    2001    2011
# 32         Uttar Pradesh  52049  61160  72195  86387  106090  131658  155317
# 4                  Bihar  27219  32261  38770  47158   57819   74317   92341
# 34           West Bengal  20018  26385  33345  40134   49370   57749   62183
# 20           Maharashtra  22802  28391  34701  40789   48396   55778   61556
# 1         Andhra Pradesh  25695  29709  35100  41063   48621   55401   56362
# 19        Madhya Pradesh  15846  19353  24440  29640   36292   44381   52557
# 28             Rajasthan  13015  16874  21222  27051   33939   43293   51500
# 16             Karnataka  14948  18320  22177  26406   31069   34889   37469
# 30            Tamil Nadu  22786  24696  28734  32456   36781   34922   37230
# 25                Odisha  14052  16439  20099  23260   27425   31287   34971

# %%
plt.bar(top_10_r_df['State/Union Territory'],top_10_r_df['2011'],color="darkred")
plt.xlabel("State/Union Territory")
plt.ylabel('Population in Rural States')
plt.title('Top 10 Rural States')
plt.xticks(rotation=45)
plt.show()

# %%
bottom_10_r_df=df.sort_values(by='2011',ascending=True)
bottom_10_r_df=bottom_10_r_df.iloc[1:11]

# %%
bottom_10_r_df
# Out:
#         State/Union Territory  1951  1961  1971  1981  1991  2001  2011
# 8                 Daman & Diu    49    37    63    79   102   158   243
# 7        Dadra & Nagar Haveli    42    58    74   104   138   220   344
# 0   Andaman & Nicobar Islands    31    64   115   189   281   356   381
# 29                     Sikkim   138   162   210   316   406   541   611
# 5                  Chandigarh    24   120   257   452   642   901  1055
# 23                    Mizoram   196   266   332   494   690   889  1097
# 26                 Puducherry   317   369   472   604   808   974  1248
# 2           Arunachal Pradesh     0   337   468   632   865  1098  1384
# 10                        Goa   547   590   795  1008  1170  1348  1459
# 24                   Nagaland   213   369   516   775  1210  1990  1979

# %%
plt.bar(bottom_10_r_df['State/Union Territory'],bottom_10_r_df['2011'],color="darkblue")
plt.xlabel("State/Union Territory")
plt.ylabel('Population in Rural States/ UTs')
plt.title('Bottom 10 Rural States/UTs')
plt.xticks(rotation=45, fontsize=8,ha='right')
plt.tight_layout()
plt.show()

# %%
df_r_long=pd.melt(top_10_r_df,id_vars='State/Union Territory',var_name='Years',value_name='Population')

# %%
plt.figure(figsize=(12, 6))

for state in df_r_long['State/Union Territory'].unique():
    state_rural_data = df_r_long[df_r_long['State/Union Territory'] == state]
    plt.plot(state_rural_data['Years'], state_rural_data['Population'], label=state)

plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Rural Population Trend by State")
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_r_long_2=pd.melt(bottom_10_r_df,id_vars='State/Union Territory',var_name='Years',value_name='Population')
df_r_long_2
# Out:
#         State/Union Territory Years  Population
# 0                 Daman & Diu  1951          49
# 1        Dadra & Nagar Haveli  1951          42
# 2   Andaman & Nicobar Islands  1951          31
# 3                      Sikkim  1951         138
# 4                  Chandigarh  1951          24
# ..                        ...   ...         ...
# 65                    Mizoram  2011        1097
# 66                 Puducherry  2011        1248
# 67          Arunachal Pradesh  2011        1384
# 68                        Goa  2011        1459
# 69                   Nagaland  2011        1979
#
# [70 rows x 3 columns]

# %%
df_r_long_2=pd.melt(bottom_10_r_df,id_vars='State/Union Territory',var_name='Years',value_name='Population')
df_r_long_2
# Out:
#         State/Union Territory Years  Population
# 0                 Daman & Diu  1951          49
# 1        Dadra & Nagar Haveli  1951          42
# 2   Andaman & Nicobar Islands  1951          31
# 3                      Sikkim  1951         138
# 4                  Chandigarh  1951          24
# ..                        ...   ...         ...
# 65                    Mizoram  2011        1097
# 66                 Puducherry  2011        1248
# 67          Arunachal Pradesh  2011        1384
# 68                        Goa  2011        1459
# 69                   Nagaland  2011        1979
#
# [70 rows x 3 columns]

# %%
df_r_long_2 = pd.melt(bottom_10_r_df, id_vars='State/Union Territory', var_name='Years', value_name='Population')

df_r_long_2['Years'] = df_r_long_2['Years'].astype(int)
plt.figure(figsize=(12, 6))

for state in df_r_long_2['State/Union Territory'].unique():
    state_rural_data = df_r_long_2[df_r_long_2['State/Union Territory'] == state]
    plt.plot(state_data['Years'], state_rural_data['Population'], label=state)

plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Rural Area Population Trend by State")
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()
